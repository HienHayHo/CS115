# %% [markdown]
# #LINEAR REGRESSION#

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import random
from sklearn.preprocessing import StandardScaler

# %%
# !gdown "1mmJxVLc8N8Bsy5w5J5M2Y0KCOXNFW8fp"
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1mmJxVLc8N8Bsy5w5J5M2Y0KCOXNFW8fp
# To: /content/Real estate.csv
# 100% 22.0k/22.0k [00:00<00:00, 54.1MB/s]

# %% [markdown]
# ##A. LOAD DATA##

# %%
df = pd.read_csv("Real estate.csv")

# %%
df
# Out:
#       No  X1 transaction date  X2 house age  \
# 0      1             2012.917          32.0
# 1      2             2012.917          19.5
# 2      3             2013.583          13.3
# 3      4             2013.500          13.3
# 4      5             2012.833           5.0
# ..   ...                  ...           ...
# 409  410             2013.000          13.7
# 410  411             2012.667           5.6
# 411  412             2013.250          18.8
# 412  413             2013.000           8.1
# 413  414             2013.500           6.5
#
#      X3 distance to the nearest MRT station  X4 number of convenience stores  \
# 0                                  84.87882                               10
# 1                                 306.59470                                9
# 2                                 561.98450                                5
# 3                                 561.98450                                5
# 4                                 390.56840                                5
# ..                                      ...                              ...
# 409                              4082.01500                                0
# 410                                90.45606                                9
# 411                               390.96960                                7
# 412                               104.81010                                5
# 413                                90.45606                                9
#
#      X5 latitude  X6 longitude  Y house price of unit area
# 0       24.98298     121.54024                        37.9
# 1       24.98034     121.53951                        42.2
# 2       24.98746     121.54391                        47.3
# 3       24.98746     121.54391                        54.8
# 4       24.97937     121.54245                        43.1
# ..           ...           ...                         ...
# 409     24.94155     121.50381                        15.4
# 410     24.97433     121.54310                        50.0
# 411     24.97923     121.53986                        40.6
# 412     24.96674     121.54067                        52.5
# 413     24.97433     121.54310                        63.9
#
# [414 rows x 8 columns]

# %%
X = df.drop(["Y house price of unit area", 'No'], axis=1)

# %%
X
# Out:
#      X1 transaction date  X2 house age  \
# 0               2012.917          32.0
# 1               2012.917          19.5
# 2               2013.583          13.3
# 3               2013.500          13.3
# 4               2012.833           5.0
# ..                   ...           ...
# 409             2013.000          13.7
# 410             2012.667           5.6
# 411             2013.250          18.8
# 412             2013.000           8.1
# 413             2013.500           6.5
#
#      X3 distance to the nearest MRT station  X4 number of convenience stores  \
# 0                                  84.87882                               10
# 1                                 306.59470                                9
# 2                                 561.98450                                5
# 3                                 561.98450                                5
# 4                                 390.56840                                5
# ..                                      ...                              ...
# 409                              4082.01500                                0
# 410                                90.45606                                9
# 411                               390.96960                                7
# 412                               104.81010                                5
# 413                                90.45606                                9
#
#      X5 latitude  X6 longitude
# 0       24.98298     121.54024
# 1       24.98034     121.53951
# 2       24.98746     121.54391
# 3       24.98746     121.54391
# 4       24.97937     121.54245
# ..           ...           ...
# 409     24.94155     121.50381
# 410     24.97433     121.54310
# 411     24.97923     121.53986
# 412     24.96674     121.54067
# 413     24.97433     121.54310
#
# [414 rows x 6 columns]

# %%
Y = df["Y house price of unit area"]

# %%
Y
# Out:
# 0      37.9
# 1      42.2
# 2      47.3
# 3      54.8
# 4      43.1
#        ...
# 409    15.4
# 410    50.0
# 411    40.6
# 412    52.5
# 413    63.9
# Name: Y house price of unit area, Length: 414, dtype: float64

# %%
Y_data = Y.to_numpy()
Y_data
# Out:
# array([ 37.9,  42.2,  47.3,  54.8,  43.1,  32.1,  40.3,  46.7,  18.8,
#         22.1,  41.4,  58.1,  39.3,  23.8,  34.3,  50.5,  70.1,  37.4,
#         42.3,  47.7,  29.3,  51.6,  24.6,  47.9,  38.8,  27. ,  56.2,
#         33.6,  47. ,  57.1,  22.1,  25. ,  34.2,  49.3,  55.1,  27.3,
#         22.9,  25.3,  47.7,  46.2,  15.9,  18.2,  34.7,  34.1,  53.9,
#         38.3,  42. ,  61.5,  13.4,  13.2,  44.2,  20.7,  27. ,  38.9,
#         51.7,  13.7,  41.9,  53.5,  22.6,  42.4,  21.3,  63.2,  27.7,
#         55. ,  25.3,  44.3,  50.7,  56.8,  36.2,  42. ,  59. ,  40.8,
#         36.3,  20. ,  54.4,  29.5,  36.8,  25.6,  29.8,  26.5,  40.3,
#         36.8,  48.1,  17.7,  43.7,  50.8,  27. ,  18.3,  48. ,  25.3,
#         45.4,  43.2,  21.8,  16.1,  41. ,  51.8,  59.5,  34.6,  51. ,
#         62.2,  38.2,  32.9,  54.4,  45.7,  30.5,  71. ,  47.1,  26.6,
#         34.1,  28.4,  51.6,  39.4,  23.1,   7.6,  53.3,  46.4,  12.2,
#         13. ,  30.6,  59.6,  31.3,  48. ,  32.5,  45.5,  57.4,  48.6,
#         62.9,  55. ,  60.7,  41. ,  37.5,  30.7,  37.5,  39.5,  42.2,
#         20.8,  46.8,  47.4,  43.5,  42.5,  51.4,  28.9,  37.5,  40.1,
#         28.4,  45.5,  52.2,  43.2,  45.1,  39.7,  48.5,  44.7,  28.9,
#         40.9,  20.7,  15.6,  18.3,  35.6,  39.4,  37.4,  57.8,  39.6,
#         11.6,  55.5,  55.2,  30.6,  73.6,  43.4,  37.4,  23.5,  14.4,
#         58.8,  58.1,  35.1,  45.2,  36.5,  19.2,  42. ,  36.7,  42.6,
#         15.5,  55.9,  23.6,  18.8,  21.8,  21.5,  25.7,  22. ,  44.3,
#         20.5,  42.3,  37.8,  42.7,  49.3,  29.3,  34.6,  36.6,  48.2,
#         39.1,  31.6,  25.5,  45.9,  31.5,  46.1,  26.6,  21.4,  44. ,
#         34.2,  26.2,  40.9,  52.2,  43.5,  31.1,  58. ,  20.9,  48.1,
#         39.7,  40.8,  43.8,  40.2,  78.3,  38.5,  48.5,  42.3,  46. ,
#         49. ,  12.8,  40.2,  46.6,  19. ,  33.4,  14.7,  17.4,  32.4,
#         23.9,  39.3,  61.9,  39. ,  40.6,  29.7,  28.8,  41.4,  33.4,
#         48.2,  21.7,  40.8,  40.6,  23.1,  22.3,  15. ,  30. ,  13.8,
#         52.7,  25.9,  51.8,  17.4,  26.5,  43.9,  63.3,  28.8,  30.7,
#         24.4,  53. ,  31.7,  40.6,  38.1,  23.7,  41.1,  40.1,  23. ,
#        117.5,  26.5,  40.5,  29.3,  41. ,  49.7,  34. ,  27.7,  44. ,
#         31.1,  45.4,  44.8,  25.6,  23.5,  34.4,  55.3,  56.3,  32.9,
#         51. ,  44.5,  37. ,  54.4,  24.5,  42.5,  38.1,  21.8,  34.1,
#         28.5,  16.7,  46.1,  36.9,  35.7,  23.2,  38.4,  29.4,  55. ,
#         50.2,  24.7,  53. ,  19.1,  24.7,  42.2,  78. ,  42.8,  41.6,
#         27.3,  42. ,  37.5,  49.8,  26.9,  18.6,  37.7,  33.1,  42.5,
#         31.3,  38.1,  62.1,  36.7,  23.6,  19.2,  12.8,  15.6,  39.6,
#         38.4,  22.8,  36.5,  35.6,  30.9,  36.3,  50.4,  42.9,  37. ,
#         53.5,  46.6,  41.2,  37.9,  30.8,  11.2,  53.7,  47. ,  42.3,
#         28.6,  25.7,  31.3,  30.1,  60.7,  45.3,  44.9,  45.1,  24.7,
#         47.1,  63.3,  40. ,  48. ,  33.1,  29.5,  24.8,  20.9,  43.1,
#         22.8,  42.1,  51.7,  41.5,  52.2,  49.5,  23.8,  30.5,  56.8,
#         37.4,  69.7,  53.3,  47.3,  29.3,  40.3,  12.9,  46.6,  55.3,
#         25.6,  27.3,  67.7,  38.6,  31.3,  35.3,  40.3,  24.7,  42.5,
#         31.9,  32.2,  23. ,  37.3,  35.5,  27.7,  28.5,  39.7,  41.2,
#         37.2,  40.5,  22.3,  28.1,  15.4,  50. ,  40.6,  52.5,  63.9])

# %% [markdown]
# ##B. SPLIT TRAIN AND TEST##

# %%
X_Train, y_train, X_Test, y_test = X[:300], Y_data[:300], X[300:], Y_data[300:]
X_Train.shape
# Out:
# (300, 6)

# %%
X_Train
# Out:
#      X1 transaction date  X2 house age  \
# 0               2012.917          32.0
# 1               2012.917          19.5
# 2               2013.583          13.3
# 3               2013.500          13.3
# 4               2012.833           5.0
# ..                   ...           ...
# 295             2013.167          18.2
# 296             2012.750          12.5
# 297             2012.833          34.9
# 298             2013.333          16.7
# 299             2013.167          33.2
#
#      X3 distance to the nearest MRT station  X4 number of convenience stores  \
# 0                                  84.87882                               10
# 1                                 306.59470                                9
# 2                                 561.98450                                5
# 3                                 561.98450                                5
# 4                                 390.56840                                5
# ..                                      ...                              ...
# 295                              2179.59000                                3
# 296                              1144.43600                                4
# 297                               567.03490                                4
# 298                              4082.01500                                0
# 299                               121.72620                               10
#
#      X5 latitude  X6 longitude
# 0       24.98298     121.54024
# 1       24.98034     121.53951
# 2       24.98746     121.54391
# 3       24.98746     121.54391
# 4       24.97937     121.54245
# ..           ...           ...
# 295     24.96299     121.51252
# 296     24.99176     121.53456
# 297     24.97003     121.54580
# 298     24.94155     121.50381
# 299     24.98178     121.54059
#
# [300 rows x 6 columns]

# %% [markdown]
# ##C. NORMALIZE FEATURES##

# %%
#@title Using sklearn.preprocessing.StandardScaler()

# SC = StandardScaler()
# SC.fit(X_Train)

# %%
#@title Standardization
def normalize(X):
  df = X.copy(deep=False)
  scale = []
  cols = df.columns.values
  for col in cols:
    mean = df[col].mean()
    std = df[col].std()
    df[col] = (df[col] - mean)/std
    scale.append([mean, std])
  return df, scale

# %%
X_Train_normalized, scale_X = normalize(X_Train)
X_train = X_Train_normalized.to_numpy()

# %%
X_train
# Out:
# array([[-0.84629424,  1.25008516, -0.78463247,  2.00992087,  1.11516979,
#          0.44291319],
#        [-0.84629424,  0.14532722, -0.61133742,  1.6677096 ,  0.90443608,
#          0.39555876],
#        [ 1.53276968, -0.40263271, -0.41172255,  0.29886451,  1.47277851,
#          0.68098277],
#        ...,
#        [-1.14635635,  1.506389  , -0.40777512, -0.04334676,  0.08145709,
#          0.80358535],
#        [ 0.63972767, -0.10213855,  2.33956365, -1.41219185, -2.19191261,
#         -1.92026787],
#        [ 0.04674777,  1.35614192, -0.75583224,  2.00992087,  1.01938174,
#          0.46561738]])

# %%
#@title Save Scale_X to normalize X_Test
scale_X
# Out:
# [[2013.1539133333338, 0.2799420373992398],
#  [17.855666666666664, 11.314695858194053],
#  [1088.747563266667, 1279.4126980517897],
#  [4.126666666666667, 2.9221714257884557],
#  [24.969009533333338, 0.012527658835628343],
#  [121.53341220000001, 0.0154156617953506]]

# %% [markdown]
# ##D. LINEAR REGRESSION IMPLEMENTATION##

# %%
#@title Predict
def predict(x, w, b):
  return sum(a*b for a, b in zip(w, x)) + b

# %%
#@title Compute Loss
def compute_loss(y_pred, y_data):
  return (y_pred-y_data)**2

# %%
#@title Linear Regression

def linear_regression(X_data, y_data, lr=0.001, epochs=10000):
  w = np.array([random.uniform(0, 1) for _ in range(X_data.shape[1])])
  b = random.uniform(0, 1)

  losses = []
  N = len(X_data)

  for _ in range(epochs):

    total_w = np.zeros(X_data.shape[1])
    total_b = 0
    loss_each = 0

    for x, y in zip(X_data, y_data):
      y_pred = predict(x, w, b)
      loss = compute_loss(y_pred, y)
      loss_each += loss
      gradient_w = np.array([(y_pred - y)*xi for xi in x])
      gradient_b = y_pred - y
      total_w = total_w + gradient_w
      total_b += gradient_b

    total_w = total_w/N
    total_b = total_b/N
    w = [x - lr*y for x, y in zip(w, total_w)]
    b = b - lr*total_b
    losses.append(loss_each/N)

  return w, b, losses

# %% [markdown]
# ##E. TRAINING##

# %%
w, b, losses = linear_regression(X_train, y_train)
w
# Out:
# [1.2729305008806437,
#  -3.450003223613457,
#  -4.532530442146386,
#  3.365138626169477,
#  3.4059875696121673,
#  0.4640704865250316]

# %%
b
# Out:
# 38.02995744347913

# %%
plt.plot(losses)
plt.xlabel("epoch")
plt.ylabel("loss value")
plt.show()

# %% [markdown]
# ##F. EVALUATION##

# %%
X_Test
# Out:
#      X1 transaction date  X2 house age  \
# 300             2013.083           2.5
# 301             2012.750          38.0
# 302             2013.500          16.5
# 303             2013.500          38.3
# 304             2013.417          20.0
# ..                   ...           ...
# 409             2013.000          13.7
# 410             2012.667           5.6
# 411             2013.250          18.8
# 412             2013.000           8.1
# 413             2013.500           6.5
#
#      X3 distance to the nearest MRT station  X4 number of convenience stores  \
# 300                               156.24420                                4
# 301                               461.78480                                0
# 302                              2288.01100                                3
# 303                               439.71050                                0
# 304                              1626.08300                                3
# ..                                      ...                              ...
# 409                              4082.01500                                0
# 410                                90.45606                                9
# 411                               390.96960                                7
# 412                               104.81010                                5
# 413                                90.45606                                9
#
#      X5 latitude  X6 longitude
# 300     24.96696     121.53992
# 301     24.97229     121.53445
# 302     24.95885     121.51359
# 303     24.97161     121.53423
# 304     24.96622     121.51668
# ..           ...           ...
# 409     24.94155     121.50381
# 410     24.97433     121.54310
# 411     24.97923     121.53986
# 412     24.96674     121.54067
# 413     24.97433     121.54310
#
# [114 rows x 6 columns]

# %%
#@title Normalize Test with Scale_X
def normalize_test(X_temp, scale_X):
  X = X_temp.copy(deep=False)
  cols = X.columns
  i = 0
  for col in cols:
    X[col] = (X[col] - scale_X[i][0])/scale_X[i][1]
    i += 1
  return X

# %%
x_test_normalized = normalize_test(X_Test, scale_X)
x_test = x_test_normalized.to_numpy()
x_test
# Out:
# array([[-0.25331434, -1.35714356, -0.72885267, -0.04334676, -0.16360067,
#          0.42215508],
#        [-1.4428463 ,  1.78036896, -0.4900395 , -1.41219185,  0.26185792,
#          0.06732114],
#        [ 1.23627973, -0.11981468,  0.93735465, -0.38555803, -0.81096823,
#         -0.23172537],
#        [ 0.34323772,  0.79050586, -0.47364659,  0.29886451,  0.4246976 ,
#          0.33847395],
#        [-0.25331434, -0.90640233,  0.84904772, -0.38555803, -0.47571006,
#         -1.35396068],
#        [-1.14635635, -0.45566109, -0.7044367 , -1.06998058,  0.38877708,
#         -0.23367145],
#        [-1.73933625,  1.15286646, -0.72439922,  1.6677096 ,  1.15907265,
#          0.40528912],
#        [ 0.63972767, -0.12865274, -0.62483573,  0.29886451,  1.03933758,
#          0.65308906],
#        [-1.73933625,  0.45465944, -0.74858806,  0.64107578, -0.98817612,
#          0.27490224],
#        [ 0.04674777, -1.41017195, -0.56010775,  0.98328705,  0.31294488,
#          0.44421058],
#        [-0.54980429, -1.11851585,  1.03191522, -1.41219185, -1.11429705,
#          1.7013736 ],
#        [ 0.93978978,  0.05694659,  0.84960579, -0.38555803, -0.45575422,
#         -1.36109628],
#        [-0.54980429, -0.36728046,  2.33956365, -1.41219185, -2.19191261,
#         -1.92026787],
#        [-1.73933625, -1.0831636 , -0.78027325,  1.6677096 ,  0.4246976 ,
#          0.6284388 ],
#        [ 0.34323772,  0.08346078, -0.54538927,  0.98328705,  0.81583214,
#          0.41826294],
#        [-0.54980429, -0.86221201, -0.76905401,  0.29886451, -0.18116181,
#          0.4708069 ],
#        [ 1.23627973, -1.00362103, -0.78027325,  1.6677096 ,  0.4246976 ,
#          0.6284388 ]])

# %%
#@title Predict in Test set
y_pred = [predict(x, w, b) for x in x_test]
y_pred
# Out:
# [45.18602250347297,
#  28.44305991907403,
#  31.11210006931114,
#  31.64862947795643,
#  34.10923832481198,
#  45.89319867509189,
#  41.47505761141753,
#  24.13989723961146,
#  47.350954613591554,
#  23.693834633109958,
#  32.465247217566194,
#  40.41229492161657,
#  43.65367078178761,
#  45.850871757574765,
#  47.98140826222356,
#  36.9786502976945,
#  45.619837611463026,
#  38.08607884065829,
#  55.44718926711631,
#  33.77755612279599,
#  12.666227644118795,
#  42.91733199736573,
#  39.64912206003182,
#  43.5805529423546,
#  30.987696507327676,
#  39.235034586170556,
#  47.7296624710243,
#  45.702710849184044,
#  34.20291845822492,
#  13.772516710875657,
#  22.967625496657597,
#  12.80454041746313,
#  32.49630393112481,
#  43.352356568813356,
#  40.281477428756894,
#  40.85931597264064,
#  38.86812305807148,
#  35.51836593731659,
#  41.552468144503756,
#  51.46002177704274,
#  33.199118569742296,
#  39.32398429437692,
#  50.40917072928025,
#  42.553294691634555,
#  30.015833212586493,
#  40.22507503731968,
#  34.154106970499356,
#  12.375408335876248,
#  47.92046487424889,
#  43.352356568813356,
#  40.93847299746666,
#  33.43038653092509,
#  26.670291505985745,
#  36.49424447316831,
#  32.22681094783391,
#  49.790709327083505,
#  39.681890953887056,
#  53.1312425124318,
#  47.85510609578439,
#  30.90544039426997,
#  45.54876379942073,
#  39.28343692389883,
#  45.1196175369138,
#  49.137697766961594,
#  41.74680475985615,
#  30.22917991286319,
#  27.00567416137527,
#  30.639435329344998,
#  39.81614011270534,
#  27.71202551958634,
#  44.47048120566756,
#  44.17585027404679,
#  38.56080702672715,
#  43.92697095790378,
#  48.832760481113866,
#  30.798945993734407,
#  33.76941395720429,
#  48.470675053719475,
#  40.018118791216516,
#  51.89335038662132,
#  47.67029738508392,
#  55.22179532192423,
#  13.837120406758242,
#  37.03711322330623,
#  13.444490958903618,
#  51.531539851839916,
#  40.97989723233373,
#  31.17811398868337,
#  34.44540069430262,
#  39.19787509298343,
#  44.16104484989076,
#  32.7885959386276,
#  37.52424518305771,
#  43.284450500907106,
#  15.9044533393388,
#  39.335912192718226,
#  28.275987669793295,
#  46.41134456132173,
#  33.76941395720429,
#  39.34885489168083,
#  40.49575608390815,
#  33.44021022358286,
#  38.95073543820177,
#  44.869815538183474,
#  46.96899639442897,
#  36.55949218497864,
#  50.07419590720438,
#  28.753844955595806,
#  31.697520459096104,
#  14.884082034424708,
#  50.43966207670003,
#  46.93264358502429,
#  44.39766294073066,
#  53.95299228995896]

# %%
#@title Result
result = pd.DataFrame(
    {"Y_pred": y_pred, "y_test": y_test},
    index=range(1, len(y_pred)+1)
)
result
# Out:
#         Y_pred  y_test
# 1    45.186023    36.9
# 2    28.443060    35.7
# 3    31.112100    23.2
# 4    31.648629    38.4
# 5    34.109238    29.4
# ..         ...     ...
# 110  14.884082    15.4
# 111  50.439662    50.0
# 112  46.932644    40.6
# 113  44.397663    52.5
# 114  53.952992    63.9
#
# [114 rows x 2 columns]

# %%
result['% Difference'] = ((abs(result['Y_pred']-result['y_test']))/result['y_test'])*100
result
# Out:
#         Y_pred  y_test  % Difference
# 1    45.186023    36.9     22.455346
# 2    28.443060    35.7     20.327563
# 3    31.112100    23.2     34.103880
# 4    31.648629    38.4     17.581694
# 5    34.109238    29.4     16.017817
# ..         ...     ...           ...
# 110  14.884082    15.4      3.350117
# 111  50.439662    50.0      0.879324
# 112  46.932644    40.6     15.597644
# 113  44.397663    52.5     15.433023
# 114  53.952992    63.9     15.566522
#
# [114 rows x 3 columns]

# %%
print('Number of tests with less than 5% difference:',result['% Difference'][result['% Difference'] <= 5.0].count())
print('Number of tests with less than 10% difference:',result['% Difference'][result['% Difference'] <= 10.0].count())
# Out:
# Number of tests with less than 5% difference: 18
# Number of tests with less than 10% difference: 38

# %% [markdown]
# #TEST WITH SKLEARN#

# %%
from sklearn.linear_model import LinearRegression
reg = LinearRegression()
reg.fit(X_Train, y_train)
# Out:
# LinearRegression()

# %%
y_pred2 = reg.predict(X_Test)

# %%
result2 = pd.DataFrame(
    {"Y_pred": y_pred2, "y_test": y_test},
    index=range(1, len(y_pred2)+1)
)
result2['% Difference'] = ((abs(result2['Y_pred']-result2['y_test']))/result2['y_test'])*100

# %%
result2
# Out:
#         Y_pred  y_test  % Difference
# 1    45.593498    36.9     23.559615
# 2    29.046808    35.7     18.636391
# 3    31.399548    23.2     35.342879
# 4    32.362893    38.4     15.721632
# 5    34.628113    29.4     17.782696
# ..         ...     ...           ...
# 110  14.693603    15.4      4.586993
# 111  50.285556    50.0      0.571111
# 112  46.829187    40.6     15.342826
# 113  44.744099    52.5     14.773145
# 114  53.881670    63.9     15.678137
#
# [114 rows x 3 columns]

# %%
print('Number of tests with less than 5% error:', result2['% Difference'][result2['% Difference'] <= 5.0].count())
print('Number of tests with less than 10% error:', result2['% Difference'][result2['% Difference'] <= 10.0].count())
# Out:
# Number of tests with less than 5% error: 19
# Number of tests with less than 10% error: 38
